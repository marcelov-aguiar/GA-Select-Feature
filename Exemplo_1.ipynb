# %%
import sys
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import TransformedTargetRegressor
from lightgbm import LGBMRegressor
from ga_selects_features import GASelectsFeatures

# %%
path = Path(sys.path[0]).joinpath("1_data").joinpath("FD001.csv")
df_data = pd.read_csv(str(path))

# %%
input_features = ['time', 'setting_1', 'setting_2', 'setting_3',
   'sensor_1', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_5', 'sensor_6',
   'sensor_7', 'sensor_8', 'sensor_9', 'sensor_10', 'sensor_11',
   'sensor_12', 'sensor_13', 'sensor_14', 'sensor_15', 'sensor_16',
   'sensor_17', 'sensor_18', 'sensor_19', 'sensor_20', 'sensor_21']
target = 'RUL'

X = df_data[input_features]
y = df_data[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

model = LGBMRegressor(max_depth=4, n_estimators=12, boosting_type="gbdt", verbose=0)
pipeline = Pipeline([('std', StandardScaler()), ('regressor', model)])
model = TransformedTargetRegressor(regressor=pipeline,
                                   transformer=StandardScaler())

# %%
ga_selects_features = GASelectsFeatures(input_model=input_features)
best_features = ga_selects_features.transform(model=model,
                                              X_train=X_train,
                                              X_val=X_val,
                                              y_train=y_train,
                                              y_val=y_val)
print(best_features)
# Out:
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# gen	nevals	Mean         	Max          	Min
# 0  	200   	[45.35700041]	[51.37499595]	[41.14260425]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 1  	175   	[43.59095936]	[53.08899324]	[41.1746566]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 2  	183   	[43.42218589]	[55.63494737]	[41.16571089]
# 3  	182   	[43.0740593] 	[52.03889157]	[41.13065842]
# 4  	175   	[42.87290522]	[51.06619352]	[41.13065842]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 5  	184   	[43.18411623]	[50.55917122]	[41.13804856]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 6  	184   	[42.91904336]	[50.48567419]	[41.13453379]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 7  	174   	[43.25979239]	[52.03562544]	[41.13860617]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 8  	184   	[43.06492984]	[55.69526589]	[41.1373537]
# 9  	181   	[43.07324471]	[50.72341992]	[41.14040344]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 10 	182   	[43.07004413]	[50.48639806]	[41.13710442]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 11 	175   	[42.92890218]	[50.31661002]	[41.13055006]
# 12 	178   	[43.06489007]	[51.44101142]	[41.12498119]
# 13 	174   	[42.88591286]	[51.28925855]	[41.12498119]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 14 	181   	[43.1698169] 	[50.91552555]	[41.12498119]
# 15 	178   	[43.18524096]	[51.39671166]	[41.12498119]
# 16 	181   	[43.02360561]	[51.85590854]	[41.12498119]
# 17 	178   	[43.41529865]	[50.31704404]	[41.1384192]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 18 	182   	[43.19822715]	[51.0674346] 	[41.16590041]
# 19 	174   	[43.15608495]	[50.59260959]	[41.14050383]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 20 	178   	[43.22658406]	[52.07572966]	[41.14050383]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 21 	179   	[42.89423207]	[50.92205147]	[41.15320791]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 22 	178   	[43.39989266]	[51.51534422]	[41.15320791]
# 23 	176   	[42.86301811]	[50.63294139]	[41.13065842]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 24 	184   	[43.07176907]	[51.01764071]	[41.13065842]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 25 	179   	[42.76762539]	[51.13849226]	[41.15702359]
# 26 	185   	[43.09856009]	[51.15611164]	[41.15201548]
# 27 	176   	[43.0124889] 	[52.05202089]	[41.13782757]
# 28 	174   	[42.66507528]	[51.09866847]	[41.13782757]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 29 	187   	[43.3313489] 	[50.96621195]	[41.13385382]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#

# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 76 	183   	[43.17368957]	[50.84002526]	[41.13917809]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 77 	180   	[43.01047206]	[50.6934989] 	[41.15133876]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 78 	186   	[43.07568381]	[59.80844084]	[41.13917809]
# 79 	178   	[42.9339261] 	[50.49482067]	[41.13453379]
# 80 	172   	[42.9569118] 	[51.52787755]	[41.13002345]
# 81 	183   	[43.40506135]	[52.89948083]	[41.15864042]
# 82 	179   	[43.63959052]	[50.78853309]	[41.14630305]
# 83 	169   	[42.91274535]	[50.92626335]	[41.13983241]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 84 	179   	[43.18112914]	[50.74004772]	[41.13547085]
# 85 	182   	[43.07123874]	[50.78165177]	[41.14260425]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 86 	183   	[43.16792926]	[52.38959661]	[41.14630305]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 87 	179   	[43.09600695]	[51.37825555]	[41.13055006]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 88 	175   	[43.08205352]	[51.85100434]	[41.12498119]
# 89 	181   	[42.82635445]	[52.12837656]	[41.12498119]
# 90 	172   	[42.7143701] 	[51.02472599]	[41.15320791]
# 91 	179   	[43.18124421]	[50.69938794]	[41.14968739]
# 92 	184   	[43.09703519]	[51.39671166]	[41.13556325]
# 93 	178   	[42.91229724]	[51.09574815]	[41.14148181]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 94 	177   	[42.79340427]	[50.85067213]	[41.14260425]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 95 	185   	[43.02041627]	[50.90990186]	[41.13547085]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 96 	176   	[43.25893693]	[51.55244663]	[41.12449435]
# 97 	186   	[42.87033087]	[51.03731312]	[41.13782757]
# 98 	181   	[42.67538556]	[51.66585271]	[41.15174079]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 99 	178   	[43.2758283] 	[51.0907798] 	[41.1384192]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100	184   	[42.93043098]	[50.76855258]	[41.13782757]
# ['time', 'setting_1', 'setting_2', 'setting_3', 'sensor_3', 'sensor_5', 'sensor_7', 'sensor_9', 'sensor_11', 'sensor_12', 'sensor_13', 'sensor_15', 'sensor_17', 'sensor_18', 'sensor_21']

# %%
best_features
# Out:
# ['time',
#  'setting_1',
#  'setting_2',
#  'setting_3',
#  'sensor_3',
#  'sensor_5',
#  'sensor_7',
#  'sensor_9',
#  'sensor_11',
#  'sensor_12',
#  'sensor_13',
#  'sensor_15',
#  'sensor_17',
#  'sensor_18',
#  'sensor_21']

# %%
model = LGBMRegressor(max_depth=4, n_estimators=12, boosting_type="gbdt", verbose=0)
pipeline = Pipeline([('std', StandardScaler()), ('regressor', model)])
model = TransformedTargetRegressor(regressor=pipeline,
                                   transformer=StandardScaler())

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

ga_selects_features.root_mean_squared_error(y_test, y_pred)
# Out:
# 39.6568687151808

# %%
model = LGBMRegressor(max_depth=4, n_estimators=12, boosting_type="gbdt", verbose=0)
pipeline = Pipeline([('std', StandardScaler()), ('regressor', model)])
model = TransformedTargetRegressor(regressor=pipeline,
                                   transformer=StandardScaler())

model.fit(X_train[best_features], y_train)

y_pred = model.predict(X_test[best_features])

ga_selects_features.root_mean_squared_error(y_test, y_pred)
# Out:
# 39.697124798843554
